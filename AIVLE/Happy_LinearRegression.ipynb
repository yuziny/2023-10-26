# %% [markdown]
# <a href="https://colab.research.google.com/github/yuziny/ML_miniproject/blob/main/Happy_LinearRegression.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Happy

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import warnings

warnings.filterwarnings(action='ignore')
# %config inlineBackend.figure_format = 'retina'

# %%
path = 'https://raw.githubusercontent.com/Jangrae/csv/master/income_happy.csv'
data = pd.read_csv(path)

# %%
data.head()
# Out:
#      income  happiness
# 0  3.862647   2.314489
# 1  4.979381   3.433490
# 2  4.923957   4.599373
# 3  3.214372   2.791114
# 4  7.196409   5.596398

# %%
data.tail()
# Out:
#        income  happiness
# 493  5.249209   4.568705
# 494  3.471799   2.535002
# 495  6.087610   4.397451
# 496  3.440847   2.070664
# 497  4.530545   3.710193

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 498 entries, 0 to 497
# Data columns (total 2 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   income     498 non-null    float64
#  1   happiness  498 non-null    float64
# dtypes: float64(2)
# memory usage: 7.9 KB

# %%
data.size
# Out:
# 996

# %%
data.describe()
# Out:
#            income   happiness
# count  498.000000  498.000000
# mean     4.466902    3.392859
# std      1.737527    1.432813
# min      1.506275    0.266044
# 25%      3.006256    2.265864
# 50%      4.423710    3.472536
# 75%      5.991913    4.502621
# max      7.481521    6.863388

# %%
data.corr()
# Out:
#              income  happiness
# income     1.000000   0.865634
# happiness  0.865634   1.000000

# %% [markdown]
# 전처리

# %%
target = 'happiness'

x = data.drop(target, axis=1)
y = data.loc[:, target]

# %%
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size=0.3, random_state=1)

# %%
x_train.shape, x_test.shape, y_train.shape, y_test.shape
# Out:
# ((348, 1), (150, 1), (348,), (150,))

# %% [markdown]
# 모델링

# %%
from sklearn.linear_model import LinearRegression

model = LinearRegression()
model.fit(x_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(x_test)

# %% [markdown]
# 회귀 성능평가

# %%
# Mean Absolute Error
from sklearn.metrics import mean_absolute_error

print('MAE: ', mean_absolute_error(y_test, y_pred))
# Out:
# MAE:  0.5588237111283767

# %%
# Mean Squared Error
from sklearn.metrics import mean_squared_error

print('MSE: ', mean_squared_error(y_test, y_pred))
# Out:
# MSE:  0.49834125870443385

# %%
# Root Mean Squared Error
from sklearn.metrics import mean_squared_error

print('RMSE: ', mean_squared_error(y_test, y_pred, squared=False))
# Out:
# RMSE:  0.7059328995764639

# %%
# Mean Absolute Percentage Error
from sklearn.metrics import mean_absolute_percentage_error

print('MAPE: ', mean_absolute_percentage_error(y_test, y_pred))
# Out:
# MAPE:  0.2534283507792002

# %%
# R2-Score
from sklearn.metrics import r2_score

print('R2: ', r2_score(y_test, y_pred))
# Out:
# R2:  0.7545536758581622

# %%
model.score(x_test, y_test)  # 평가성능
# Out:
# 0.7545536758581622

# %%
model.score(x_train, y_train) # 학습성능
# Out:
# 0.7467917792688501

# %%
# 평가성능이 낮고 학습성능이 높으면 과대적합
# 평가성능이 높고 학습성능이 낮으면 과소적합
